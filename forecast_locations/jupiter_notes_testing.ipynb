# %%
import folium
import json

# in future improve to pull data directly from the gazetteer.
# curently not working, probably needs a token or credentials
'''
import requests
def download_file_from_git(url, filename):
    raw_url = url.replace('github.com', 'raw.githubusercontent.com').replace('/blob', '')

    print(raw_url)
    response = requests.get(raw_url)
    with open(filename, 'w') as file:
        file.write(response.text)

# Usage
url = 'https://github.com/MetOffice/locations-search-pkg-os/blob/master/src/main/resources/gazetteer/bra_.txt'
filename = 'gaz.txt'
download_file_from_git(url, filename)
'''

# Manual input location info from Gazetteer
# https://github.com/MetOffice/locations-search-pkg-os/tree/master/src/main/resources/gazetteer
c_lon = -3.53
c_lat = 50.48
name = "Gazetteer Torquay (Torbay)"

# %%
# Create basic map and add the gazetteer location
map_uk = folium.Map(location=[c_lat,c_lon], zoom_start=14)
folium.Marker([c_lat,c_lon], 
              icon=folium.Icon(icon="home",color="red"),
              popup=name,
              ).add_to(map_uk)

# %%
# Add all forecast locations within 0.2 lat and 0.2 lon of the gazetteer location
f = open('forecast_locations.json')
forecast_locations = json.load(f)
for i in forecast_locations:
    if i['domestic'] == True:
        lat = i['position']['lat']
        lon = i['position']['lon']
        name = i['name']
        
        if (lat < c_lat + 0.2 and lat > c_lat - 0.2 and lon < c_lon + 0.2 and lon > c_lon - 0.2):
            folium.Marker([lat,lon], 
                          popup=f"Forcast Location: {name}",
                          icon=folium.Icon(icon="info-sign")).add_to(map_uk)

# %%
# !mkdir map_output_files
map_uk.save('map_output_files/forecast_locations_map_uk.html')
map_uk
# Out:
# A subdirectory or file map_output_files already exists.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f533797fef33e37a10cb1f50437c3050 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f533797fef33e37a10cb1f50437c3050&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f533797fef33e37a10cb1f50437c3050 = L.map(
#                 &quot;map_f533797fef33e37a10cb1f50437c3050&quot;,
#                 {
#                     center: [50.48, -3.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b628facf6ecd5dbdef0ea9a33fc9dcee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f533797fef33e37a10cb1f50437c3050);
#
#
#             var marker_3fcf6b87af9e60e5fd93d9fbbe3af665 = L.marker(
#                 [50.48, -3.53],
#                 {}
#             ).addTo(map_f533797fef33e37a10cb1f50437c3050);
#
#
#             var icon_1750902aae17426e2257afbf895b2517 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3fcf6b87af9e60e5fd93d9fbbe3af665.setIcon(icon_1750902aae17426e2257afbf895b2517);
#
#
#         var popup_d7aa6989d1116b1bc980084de4318e2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b28857096df7bdde99f32434e6f2445c = $(`&lt;div id=&quot;html_b28857096df7bdde99f32434e6f2445c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gazetteer Torquay (Torbay)&lt;/div&gt;`)[0];
#                 popup_d7aa6989d1116b1bc980084de4318e2f.setContent(html_b28857096df7bdde99f32434e6f2445c);
#
#
#
#         marker_3fcf6b87af9e60e5fd93d9fbbe3af665.bindPopup(popup_d7aa6989d1116b1bc980084de4318e2f)
#         ;
#
#
#
#
#             var marker_faeea29534f47231d29f5f1e59205566 = L.marker(
#                 [50.65855, -3.53605],
#                 {}
#             ).addTo(map_f533797fef33e37a10cb1f50437c3050);
#
#
#             var icon_01377ffbe9e14ede41dc62b2155cf9cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_faeea29534f47231d29f5f1e59205566.setIcon(icon_01377ffbe9e14ede41dc62b2155cf9cb);
#
#
#         var popup_95ba41680d119d24d180fbefcb93cc7c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c4204083bab99ad4849f2aea6821c12 = $(`&lt;div id=&quot;html_6c4204083bab99ad4849f2aea6821c12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Forcast Location: Kennford&lt;/div&gt;`)[0];
#                 popup_95ba41680d119d24d180fbefcb93cc7c.setContent(html_6c4204083bab99ad4849f2aea6821c12);
#
#
#
#         marker_faeea29534f47231d29f5f1e59205566.bindPopup(popup_95ba41680d119d24d180fbefcb93cc7c)
#         ;
#
#
#
#
#             var marker_026d0e4a64639f3e70b7460883fefe96 = L.marker(
#                 [50.4818, -3.7238],
#                 {}
#             ).addTo(map_f533797fef33e37a10cb1f50437c3050);
#
#
#             var icon_ff692b5b6f4759f91d40be4d9850f7e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_026d0e4a64639f3e70b7460883fefe96.setIcon(icon_ff692b5b6f4759f91d40be4d9850f7e1);
#
#
#         var popup_3c9ede85f9d164b32e858c4fd348ef2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea96dc13d648414bde06bf4413511b86 = $(`&lt;div id=&quot;html_ea96dc13d648414bde06bf4413511b86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Forcast Location: Landscove&lt;/div&gt;`)[0];
#                 popup_3c9ede85f9d164b32e858c4fd348ef2a.setContent(html_ea96dc13d648414bde06bf4413511b86);
#
#
#
#         marker_026d0e4a64639f3e70b7460883fefe96.bindPopup(popup_3c9ede85f9d164b32e858c4fd348ef2a)
#         ;
#
#
#
#
#             var marker_9103e99c0b776b8ca12e68d9e4749ad8 = L.marker(
#                 [50.4959, -3.5154],
#                 {}
#             ).addTo(map_f533797fef33e37a10cb1f50437c3050);
#
#
#             var icon_ed51967f9b9c867b7e6c36e9a0b691f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:
