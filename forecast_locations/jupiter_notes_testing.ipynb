# %%
import folium
import json

# in future improve to pull data directly from the gazetteer.
# curently not working, probably needs a token or credentials
'''
import requests
def download_file_from_git(url, filename):
    raw_url = url.replace('github.com', 'raw.githubusercontent.com').replace('/blob', '')

    print(raw_url)
    response = requests.get(raw_url)
    with open(filename, 'w') as file:
        file.write(response.text)

# Usage
url = 'https://github.com/MetOffice/locations-search-pkg-os/blob/master/src/main/resources/gazetteer/bra_.txt'
filename = 'gaz.txt'
download_file_from_git(url, filename)
'''

# Manual input location info from Gazetteer
# https://github.com/MetOffice/locations-search-pkg-os/tree/master/src/main/resources/gazetteer
c_lon = -3.39
c_lat = 57.00
name = "Gazetteer Braemar"

# %%
# Create basic map and add the gazetteer location
map_uk = folium.Map(location=[c_lat,c_lon], zoom_start=14)
folium.Marker([c_lat,c_lon], 
              icon=folium.Icon(icon="home",color="red"),
              popup=name,
              ).add_to(map_uk)

# %%
# Add all forecast locations within 0.2 lat and 0.2 lon of the gazetteer location
f = open('forecast_locations.json')
forecast_locations = json.load(f)
for i in forecast_locations:
    if i['domestic'] == True:
        lat = i['position']['lat']
        lon = i['position']['lon']
        name = i['name']
        
        if (lat < c_lat + 0.2 and lat > c_lat - 0.2 and lon < c_lon + 0.2 and lon > c_lon - 0.2):
            folium.Marker([lat,lon], 
                          popup=f"Forcast Location: {name}",
                          icon=folium.Icon(icon="info-sign")).add_to(map_uk)

# %%
# !mkdir map_output_files
map_uk.save('map_output_files/forecast_locations_map_uk.html')
map_uk
# Out:
# A subdirectory or file map_output_files already exists.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_724adf119f56eaf55735ee2421d9c086 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_724adf119f56eaf55735ee2421d9c086&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_724adf119f56eaf55735ee2421d9c086 = L.map(
#                 &quot;map_724adf119f56eaf55735ee2421d9c086&quot;,
#                 {
#                     center: [57.0, -3.39],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f04e78619737e0a5f4fbdfbc04ca3fc3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_724adf119f56eaf55735ee2421d9c086);
#
#
#             var marker_54a9258a759872b7469f90ba92849fe1 = L.marker(
#                 [57.0, -3.39],
#                 {}
#             ).addTo(map_724adf119f56eaf55735ee2421d9c086);
#
#
#             var icon_3899d556ec85cd10c1ebd2ca2fbaf3ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_54a9258a759872b7469f90ba92849fe1.setIcon(icon_3899d556ec85cd10c1ebd2ca2fbaf3ed);
#
#
#         var popup_106db8907b85b75f2ef2343f6c741a7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e43f2768b295ccb66d29aa22cc0272fa = $(`&lt;div id=&quot;html_e43f2768b295ccb66d29aa22cc0272fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gazetteer Braemar&lt;/div&gt;`)[0];
#                 popup_106db8907b85b75f2ef2343f6c741a7e.setContent(html_e43f2768b295ccb66d29aa22cc0272fa);
#
#
#
#         marker_54a9258a759872b7469f90ba92849fe1.bindPopup(popup_106db8907b85b75f2ef2343f6c741a7e)
#         ;
#
#
#
#
#             var marker_ffcaeceb09679f7174d652395549f727 = L.marker(
#                 [56.8779, -3.4209],
#                 {}
#             ).addTo(map_724adf119f56eaf55735ee2421d9c086);
#
#
#             var icon_f3d636c920915ef6f31e2a180b9d0027 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ffcaeceb09679f7174d652395549f727.setIcon(icon_f3d636c920915ef6f31e2a180b9d0027);
#
#
#         var popup_6e81e706b54e95e7068e601b8f65bf57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31d8bfe0c57d0c1821180316c0b26ea9 = $(`&lt;div id=&quot;html_31d8bfe0c57d0c1821180316c0b26ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Forcast Location: The Cairnwell&lt;/div&gt;`)[0];
#                 popup_6e81e706b54e95e7068e601b8f65bf57.setContent(html_31d8bfe0c57d0c1821180316c0b26ea9);
#
#
#
#         marker_ffcaeceb09679f7174d652395549f727.bindPopup(popup_6e81e706b54e95e7068e601b8f65bf57)
#         ;
#
#
#
#
#             var marker_4a579c36bf3d8fcbf3d74cf346a61cc7 = L.marker(
#                 [56.8508, -3.2478],
#                 {}
#             ).addTo(map_724adf119f56eaf55735ee2421d9c086);
#
#
#             var icon_393eec05219e46c0f02260a1a341f6a4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a579c36bf3d8fcbf3d74cf346a61cc7.setIcon(icon_393eec05219e46c0f02260a1a341f6a4);
#
#
#         var popup_ec9acebde33b22c334474224d7cd9502 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ccff832dea23e32628188c16947227a = $(`&lt;div id=&quot;html_8ccff832dea23e32628188c16947227a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Forcast Location: Mayar&lt;/div&gt;`)[0];
#                 popup_ec9acebde33b22c334474224d7cd9502.setContent(html_8ccff832dea23e32628188c16947227a);
#
#
#
#         marker_4a579c36bf3d8fcbf3d74cf346a61cc7.bindPopup(popup_ec9acebde33b22c334474224d7cd9502)
#         ;
#
#
#
#
#             var marker_7e196ddd737516f8927b920392314c5d = L.marker(
#                 [56.8478, -3.1954],
#                 {}
#             ).addTo(map_724adf119f56eaf55735ee2421d9c086);
#
#
#             var icon_a06bed83c2e81b4fe4b4be72e80d236b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-s
